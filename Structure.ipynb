# %% [markdown]
# # ***Structure Problem***
#
#
# > By Sonal

# %% [markdown]
# # Student structure

# %%
# %%writefile studentStruc.c
# #include <stdio.h>
#
# // Define a structure named 'student'
# struct student {
#     char name[50]; // Character array to store the student's name
#     int roll;      // Integer to store the student's roll number
#     int age;       // Integer to store the student's age
#     float marks[5]; // Array of floats to store marks in 5 subjects
# };
#
# // Main function where the program execution begins
# int main() {
#     struct student s; // Declare a variable 's' of type 'struct student'
#     float sum = 0;    // Declare a float variable 'sum' to calculate total marks, initialized to 0
#
#     printf("Enter name: "); // Prompt the user to enter the student's name
#     scanf("%s", s.name);    // Read the name and store it in s.name
#
#     printf("Enter roll no and age: "); // Prompt for roll number and age
#     scanf("%d %d", &s.roll, &s.age);    // Read roll number and age
#
#     printf("Enter marks of 5 subjects: "); // Prompt for marks in 5 subjects
#     for (int i = 0; i < 5; i++) { // Loop to read marks for each of the 5 subjects
#         scanf("%f", &s.marks[i]); // Read the mark for the current subject
#         sum += s.marks[i];        // Add the current mark to the total sum
#     }
#
#     printf("\nAverage marks: %.2f", sum / 5); // Calculate and print the average marks, formatted to two decimal places
#     return 0; // Indicate successful program execution
# }
# Out:
# Overwriting studentStruc.c

# %%
# !gcc studentStruc.c -o studentStruc.exe

# %%
# !./studentStruc.exe
# Out:
# Enter name: Saanjh
# Enter roll no and age: 5 22
# Enter marks of 5 subjects: 20
# 20
# 4
# 6
# 7
#
# Average marks: 11.40

# %% [markdown]
# # **Self -referential Structure**

# %%
# %%writefile selfRefrential.c
# #include <stdio.h>
#
# // Define a structure named 'node'
# struct node {
#     int data; // Integer data to be stored in the node
#     struct node *next; // Pointer to the next node in the list (self-referential)
# };
#
# // Main function where the program execution begins
# int main() {
#     // Declare three 'node' type variables
#     struct node n1, n2, n3;
#
#     n1.data = 40; // Assign data to the first node
#     n2.data = 90; // Assign data to the second node
#     n3.data = 140; // Assign data to the third node
#
#     n1.next = &n2; // Link n1 to n2
#     n2.next = &n3; // Link n2 to n3
#     n3.next = NULL; // Mark the end of the list for n3
#
#     struct node *ptr = &n1; // Initialize a pointer 'ptr' to the first node
#     printf("Linked list data: "); // Print a header for the linked list data
#     while (ptr != NULL) { // Traverse the linked list until 'ptr' becomes NULL
#         printf("%d ", ptr->data); // Print the data of the current node
#         ptr = ptr->next; // Move 'ptr' to the next node
#     }
#     return 0; // Indicate successful program execution
# }
# Out:
# Overwriting selfRefrential.c

# %%
# !gcc selfRefrential.c -o selfRefrential.exe

# %%
# !./selfRefrential.exe
# Out:
# Linked list data: 40 90 140

# %% [markdown]
# # **Student Above 18**

# %%
# %%writefile stu18.c
# #include <stdio.h>
#
# // Define a structure named 'student'
# struct student {
#     char name[50]; // Character array to store student's name
#     int roll;      // Integer to store student's roll number
#     int age;       // Integer to store student's age
# };
#
# // Main function where the program execution begins
# int main() {
#     struct student s[10]; // Declare an array of 10 'student' structures
#     int count = 0;        // Initialize a counter for students above 18 to 0
#
#     // Loop to get input for 10 students
#     for (int i = 0; i < 5; i++) { // Loop 10 times for 10 students
#         printf("Enter name, roll, age of student %d: ", i + 1); // Prompt for student details
#         scanf("%s%d%d", s[i].name, &s[i].roll, &s[i].age);      // Read name, roll, and age
#         if (s[i].age > 18) count++;                             // If age is greater than 18, increment count
#     }
#
#     printf("\nNumber of students above 18: %d", count); // Print the total count of students above 18
#     return 0;                                           // Indicate successful program execution
# }
# Out:
# Writing stu18.c

# %%
# !gcc stu18.c -o stu18.exe

# %%
# !./stu18.exe
# Out:
# Enter name, roll, age of student 1: Sanya 1 17
# Enter name, roll, age of student 2: Rohan 2 19
# Enter name, roll, age of student 3: Churamani 3 28
# Enter name, roll, age of student 4: Rehman 4 23
# Enter name, roll, age of student 5: Aman 5 24
# Enter name, roll, age of student 6: Aman 5 24
# Enter name, roll, age of student 7: Anany 5 14
# Enter name, roll, age of student 8: ori 8 24
# Enter name, roll, age of student 9: Aani 12 20
# Enter name, roll, age of student 10: Nani 8 90
#
# Number of students above 18: 8
